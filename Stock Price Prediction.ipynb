# %%
# All The Imported Libraries
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
# Using import os to check path
display (os.getcwd())
files = os.listdir('.')
print(files)
# Out:
# '/content'
# ['.config', 'sample_data']

# %%
# Since we are using google cloab. we will set our path to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Setting our path to google drive
os.chdir ('/content/drive/My Drive/Colab Notebooks/project/Stock_Price_Prediction_content')

# %%
# Cheacking the path
display (os.getcwd())
# Out:
# '/content/drive/My Drive/Colab Notebooks/project/Stock_Price_Prediction_content'

# %%
# setting csv file for opening and reading
df =pd.read_csv("prices.csv", header=0)

# %%
# displaying csv file
display (df)
# Out:
#                        date symbol        open       close         low  \
# 0       2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998
# 1       2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002
# 2       2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000
# 3       2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000
# 4       2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996
# ...                     ...    ...         ...         ...         ...
# 851259           2016-12-30    ZBH  103.309998  103.199997  102.849998
# 851260           2016-12-30   ZION   43.070000   43.040001   42.689999
# 851261           2016-12-30    ZTS   53.639999   53.529999   53.270000
# 851262  2016-12-30 00:00:00    AIV   44.730000   45.450001   44.410000
# 851263  2016-12-30 00:00:00    FTV   54.200001   53.630001   53.389999
#
#               high     volume
# 0       126.250000  2163600.0
# 1       125.540001  2386400.0
# ...

# %%
# checking the shape
print(df.shape)
# Out:
# (851264, 7)

# %%
# All the columns
print(df.columns)
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %%
# Number of unique sysmbol and their count
df.symbol.value_counts()
# Out:
# KSU     1762
# NOC     1762
# ORCL    1762
# OMC     1762
# OKE     1762
#         ...
# KHC      378
# HPE      304
# CSRA     284
# WLTW     251
# FTV      126
# Name: symbol, Length: 501, dtype: int64

# %%
#Name of all the unique sysmbol
df.symbol.unique()
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALL',
#        'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN',
#        'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI', 'AVB',
#        'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX',
#        'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BHI', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH',
#        'CAT', 'CB', 'CBG', 'CBS', 'CCI', 'CCL', 'CELG', 'CERN', 'CF',
#        'CHD', 'CHK', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA',
#        'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH',
#        'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS',
#        'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE',
# ...

# %%
# Number of all unique sysmbol
display(df.symbol.unique().shape)
# Out:
# (501,)

# %%
# First 20 unique sysmbol
df.symbol.unique()[0:20]
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN'], dtype=object)

# %%
# length og sysmbol values
print(len(df.symbol.values))
# Out:
# 851264

# %%
# The info of pirce csv file
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    851264 non-null  object
#  1   symbol  851264 non-null  object
#  2   open    851264 non-null  float64
#  3   close   851264 non-null  float64
#  4   low     851264 non-null  float64
#  5   high    851264 non-null  float64
#  6   volume  851264 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
df.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       70.836986      70.857109      70.118414      71.543476
# std        83.695876      83.689686      82.877294      84.465504
# min         0.850000       0.860000       0.830000       0.880000
# 25%        33.840000      33.849998      33.480000      34.189999
# 50%        52.770000      52.799999      52.230000      53.310001
# 75%        79.879997      79.889999      79.110001      80.610001
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
# checking for missing value
df.isnull().sum()
# Out:
# date      0
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %%
# show all unique date
df.date.unique()
# Out:
# array(['2016-01-05 00:00:00', '2016-01-06 00:00:00',
#        '2016-01-07 00:00:00', ..., '2016-12-28', '2016-12-29',
#        '2016-12-30'], dtype=object)

# %%
pd.DataFrame(df.date.unique())
# Out:
#                         0
# 0     2016-01-05 00:00:00
# 1     2016-01-06 00:00:00
# 2     2016-01-07 00:00:00
# 3     2016-01-08 00:00:00
# 4     2016-01-11 00:00:00
# ...                   ...
# 3519           2016-12-23
# 3520           2016-12-27
# 3521           2016-12-28
# 3522           2016-12-29
# 3523           2016-12-30
#
# [3524 rows x 1 columns]

# %%
# check for any duplicate
df.duplicated().sum()
# Out:
# 0

# %%
# Load the securities csv files
comp_info = pd.read_csv('securities.csv')

# %%
comp_info['Index'] = range(1, len(comp_info) + 1)

# %%
comp_info
# Out:
#     Ticker symbol                Security SEC filings             GICS Sector  \
# 0             MMM              3M Company     reports             Industrials
# 1             ABT     Abbott Laboratories     reports             Health Care
# 2            ABBV                  AbbVie     reports             Health Care
# 3             ACN           Accenture plc     reports  Information Technology
# 4            ATVI     Activision Blizzard     reports  Information Technology
# ..            ...                     ...         ...                     ...
# 500          YHOO              Yahoo Inc.     reports  Information Technology
# 501           YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 502           ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503          ZION           Zions Bancorp     reports              Financials
# 504           ZTS                  Zoetis     reports             Health Care
#
# ...

# %%
# Total number of company
comp_info["Ticker symbol"].nunique()
# Out:
# 505

# %%
# check for non null count and dtype
comp_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ticker symbol            505 non-null    object
#  1   Security                 505 non-null    object
#  2   SEC filings              505 non-null    object
#  3   GICS Sector              505 non-null    object
#  4   GICS Sub Industry        505 non-null    object
#  5   Address of Headquarters  505 non-null    object
#  6   Date first added         307 non-null    object
#  7   CIK                      505 non-null    int64
#  8   Index                    505 non-null    int64
# dtypes: int64(2), object(7)
# memory usage: 35.6+ KB

# %%
# check for null database
comp_info.isnull().sum()
# Out:
# Ticker symbol                0
# Security                     0
# SEC filings                  0
# GICS Sector                  0
# GICS Sub Industry            0
# Address of Headquarters      0
# Date first added           198
# CIK                          0
# Index                        0
# dtype: int64

# %%
comp_info.describe()
# Out:
#                 CIK       Index
# count  5.050000e+02  505.000000
# mean   7.074490e+05  253.000000
# std    5.144375e+05  145.925209
# min    1.800000e+03    1.000000
# 25%    8.631200e+04  127.000000
# 50%    8.310010e+05  253.000000
# 75%    1.075531e+06  379.000000
# max    1.659166e+06  505.000000

# %%
# com is used to get comany or starting name or index . we can find it.
com = input("Enter company name or starting name or index number: ")

if com.isdigit():
    # Convert the input to an integer and use it as an index
    index = int(com)
    if index >= 0 and index < len(comp_info):
        filtered_info = print(comp_info.loc[index])
        filtered_info = comp_info.loc[index]
        co = filtered_info['Security']
        print(filtered_info)
        print(co)
    else:
        print("Index out of range.")
else:
    # Search for companies whose names start with the input string
    filtered_info = (comp_info.loc[comp_info.Security.str.startswith(com) , :])
    ca = filtered_info['Security']
    co = (ca.to_string(index=False))
    if not filtered_info.empty:
        print(filtered_info)
        print(co)
    else:
        print("No matching companies found.")
# Out:
# Enter company name or starting name or index number: Face
#     Ticker symbol  Security SEC filings             GICS Sector  \
# 181            FB  Facebook     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 181  Internet Software & Services  Menlo Park, California       23-12-2013
#
#          CIK  Index
# 181  1326801    182
# Facebook

# %%
# comp_plot is used to get the symbol. for easier finding
comp_plot = comp_info.loc[(comp_info["Security"] == co),["Ticker symbol"] ]["Ticker symbol"]
print(comp_plot)
# Out:
# 181    FB
# Name: Ticker symbol, dtype: object

# %%
for i in comp_plot:
    print (i)
# Out:
# FB

# %%
# ploting code. used here to plot opening and closing stock time
def plotter(code):
    global closing_stock ,opening_stock
    f, axs = plt.subplots(2,2,figsize=(15,8))
    plt.subplot(212)
    company = df[df['symbol']==code]
    company = company.open.values.astype('float32')
    company = company.reshape(-1, 1)
    opening_stock = company
    plt.grid(True)
    plt.xlabel('Time')
    plt.ylabel(code + " open stock prices")
    plt.title('prices Vs Time')
    plt.plot(company , 'g')
    plt.subplot(211)
    company_close = df[df['symbol']==code]
    company_close = company_close.close.values.astype('float32')
    company_close = company_close.reshape(-1, 1)
    closing_stock = company_close
    plt.xlabel('Time')
    plt.ylabel(code + " close stock prices")
    plt.title('prices Vs Time')
    plt.grid(True)
    plt.plot(company_close , 'b')
    plt.show()

# %%
for i in comp_plot:
    plotter(i)

# %%
stocks= np.array (df[df.symbol.isin ([i])].close)
print(stocks)
# Out:
# [ 28.        27.77      28.76     ... 116.919998 116.349998 115.050003]

# %%
display (stocks.shape)
# Out:
# (1008,)

# %%
stocks = stocks.reshape(len(stocks) , 1)
print (stocks.shape)
print(stocks)
# Out:
# (1008, 1)
# [[ 28.      ]
#  [ 27.77    ]
#  [ 28.76    ]
#  ...
#  [116.919998]
#  [116.349998]
#  [115.050003]]

# %%
#scaling features between 0 and 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
stocks = scaler.fit_transform(stocks)
display (stocks)
# Out:
# array([[0.04620402],
#        [0.04412031],
#        [0.05308933],
#        ...,
#        [0.85178473],
#        [0.84662075],
#        [0.8348433 ]])

# %%
#we are dividing the stock for training
print (stocks.shape)
train = int(len(stocks) * 0.80)
print (train)
test = len(stocks) - train
print (test)
# Out:
# (1008, 1)
# 806
# 202

# %%
#divinding the values of stocks data to train from 0 to 1008 i.e 80% data
train = stocks[0:train]
display (train.shape)
print(train)
# Out:
# (806, 1)
# [[4.62040229e-02]
#  [4.41203121e-02]
#  [5.30893283e-02]
#  [5.90686724e-02]
#  [5.58072029e-02]
#  [6.96684188e-02]
#  [7.61007345e-02]
#  [7.99057717e-02]
#  [7.29298883e-02]
#  [6.52292088e-02]
#  [6.29643057e-02]
#  [6.55915842e-02]
#  [6.12429794e-02]
#  [7.09367645e-02]
#  [7.17521297e-02]
#  [7.41076289e-02]
#  [7.82750596e-02]
#  [8.67004991e-02]
#  [7.14803503e-02]
#  [7.55571668e-02]
#  [7.32016676e-02]
#  [6.18771522e-02]
#  [4.72005893e-02]
#  [5.20021657e-02]
#  [5.57166068e-02]
#  [5.20927709e-02]
#  [5.11868006e-02]
#  [4.85595221e-02]
#  [4.04964762e-02]
#  [4.53886578e-02]
#  [5.07338291e-02]
#  [4.91030988e-02]
#  [5.46294624e-02]
#  [5.03714355e-02]
#  [3.96811111e-02]
#  [3.83221511e-02]
#  [3.95905059e-02]
#  [4.06776503e-02]
#  [3.59666700e-02]
#  [3.94093136e-02]
#  [4.42109172e-02]
#  [4.36673224e-02]
#  [4.18554090e-02]
#  [4.12212452e-02]
#  [5.14585980e-02]
#  [4.58416293e-02]
#  [4.74723596e-02]
#  [4.46638888e-02]
#  [3.78691795e-02]
# ...

# %%
test = stocks[len(train) : ]
display(test.shape)
display (test)
# Out:
# (202, 1)
# array([[0.80884219],
#        [0.79833301],
#        [0.80222864],
#        [0.8058525 ],
#        [0.80947636],
#        [0.81210366],
#        [0.81672408],
#        [0.82252222],
#        [0.84471824],
#        [0.83167238],
#        [0.82623663],
#        [0.84399347],
#        [0.81219427],
#        [0.80920458],
#        [0.82270339],
#        [0.82206921],
#        [0.79479976],
#        [0.77994201],
#        [0.79461861],
#        [0.79371265],
#        [0.79670227],
#        [0.78583076],
#        [0.79316903],
#        [0.80983876],
#        [0.81101648],
#        [0.82025732],
#        [0.7941656 ],
#        [0.78999818],
#        [0.77785833],
#        [0.77903606],
#        [0.85006345],
#        [0.85776411],
#        [0.86673311],
#        [0.85640515],
#        [0.86211269],
#        [0.85984779],
#        [0.87506794],
#        [0.87280303],
#        [0.88421816],
#        [0.87533972],
#        [0.88222504],
#        [0.87796701],
#        [0.86763905],
# ...

# %%
# This code is used to make 2 new array. so we can predict it easily by 3 values
def process_data(data , n_features):
    dataX, dataY = [], []
    for i in range(len(data)-n_features):
        a = data[i:(i+n_features), 0]
        dataX.append(a)
        dataY.append(data[i + n_features, 0])
    return np.array(dataX), np.array(dataY)

# %%
n_features = 2
trainX, trainY = process_data(train, n_features)
print(trainX.shape , trainY.shape)
# Out:
# (804, 2) (804,)

# %%
testX, testY = process_data(test, n_features)
print (testX.shape , testY.shape)
# Out:
# (200, 2) (200,)

# %%
stocksX, stocksY = process_data(stocks, n_features)
print (stocksX.shape , stocksY.shape)
# Out:
# (1006, 2) (1006,)

# %%
display (trainX[:10])
# Out:
# array([[0.04620402, 0.04412031],
#        [0.04412031, 0.05308933],
#        [0.05308933, 0.05906867],
#        [0.05906867, 0.0558072 ],
#        [0.0558072 , 0.06966842],
#        [0.06966842, 0.07610073],
#        [0.07610073, 0.07990577],
#        [0.07990577, 0.07292989],
#        [0.07292989, 0.06522921],
#        [0.06522921, 0.06296431]])

# %%
display (trainY[:10])
# Out:
# array([0.05308933, 0.05906867, 0.0558072 , 0.06966842, 0.07610073,
#        0.07990577, 0.07292989, 0.06522921, 0.06296431, 0.06559158])

# %%
# reshaping trainX and testX to use in deep learning model
trainX = trainX.reshape(trainX.shape[0] , 1 ,trainX.shape[1])
display (trainX.shape)
# Out:
# (804, 1, 2)

# %%
#Reshape to 3D array test X
testX = testX.reshape(testX.shape[0] , 1 ,testX.shape[1])
display (testX.shape)
# Out:
# (200, 1, 2)

# %%
#Reshape to 3D array  full data set
stocksX= stocksX.reshape(stocksX.shape[0] , 1 ,stocksX.shape[1])
display (stocksX.shape)
# Out:
# (1006, 1, 2)

# %%
# importing libraries for lstm
import math
from keras.models import Sequential
from keras.layers import Dense , BatchNormalization , Dropout , Activation
from keras.layers import LSTM , GRU
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.optimizers import Adam , SGD , RMSprop

# %%
filepath="stock_weights1.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='max')
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
# making neural network for LSTM
model = Sequential()
model.add(GRU(256 , input_shape = (1 , n_features) , return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(256))
model.add(Dropout(0.4))
model.add(Dense(64 ,  activation = 'relu'))
model.add(Dense(1))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  gru (GRU)                   (None, 1, 256)            199680
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  lstm (LSTM)                 (None, 256)               525312
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 1)                 65
#
# ...
# Total params: 741,505
# Trainable params: 741,505
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Selecting the loss measurement metrics and optimizer for our model, to find out mean square error
model.compile(loss='mean_squared_error', optimizer=Adam(lr = 0.0005) , metrics = ['mean_squared_error'])

# %%
# fitting the data . training the trainX, to relate to trainY
history = model.fit(trainX, trainY, epochs=100 , batch_size = 128 ,
          callbacks = [checkpoint , lr_reduce] , validation_data = (testX,testY))
# Out:
# Epoch 1/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1825 - mean_squared_error: 0.1825
# Epoch 1: val_loss improved from -inf to 0.53335, saving model to stock_weights1.hdf5
# 7/7 [==============================] - 6s 363ms/step - loss: 0.1825 - mean_squared_error: 0.1825 - val_loss: 0.5333 - val_mean_squared_error: 0.5333 - lr: 5.0000e-04
# Epoch 2/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1004 - mean_squared_error: 0.1004
# Epoch 2: val_loss did not improve from 0.53335
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1004 - mean_squared_error: 0.1004 - val_loss: 0.2236 - val_mean_squared_error: 0.2236 - lr: 5.0000e-04
# Epoch 3/100
# 4/7 [================>.............] - ETA: 0s - loss: 0.0332 - mean_squared_error: 0.0332
# Epoch 3: val_loss did not improve from 0.53335
# ...

# %%
test_pred = model.predict(testX)
display (test_pred [:10])
# Out:
# 7/7 [==============================] - 1s 4ms/step
# array([[0.6573098 ],
#        [0.65481955],
#        [0.65726674],
#        [0.6596198 ],
#        [0.66167367],
#        [0.6639803 ],
#        [0.6673375 ],
#        [0.6760471 ],
#        [0.6798686 ],
#        [0.6736735 ]], dtype=float32)

# %%
test_pred = scaler.inverse_transform(test_pred)
display (test_pred [:10])
# Out:
# array([[95.45385 ],
#        [95.17898 ],
#        [95.449104],
#        [95.70883 ],
#        [95.93554 ],
#        [96.19015 ],
#        [96.56071 ],
#        [97.52207 ],
#        [97.94389 ],
#        [97.26008 ]], dtype=float32)

# %%
testY = testY.reshape(testY.shape[0] , 1)
#Converting reshaped list in 1D array so that we can plot it
testY = scaler.inverse_transform(testY)
display (testY[:10])
# Out:
# array([[111.449997],
#        [111.849998],
#        [112.25    ],
#        [112.540001],
#        [113.050003],
#        [113.690002],
#        [116.139999],
#        [114.699997],
#        [114.099998],
#        [116.059998]])

# %%
from sklearn.metrics import r2_score
r2_score(testY,test_pred)
# Out:
# -9.392445072188375

# %%
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(testY , 'b')
plt.plot(test_pred , 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %%
train_pred = model.predict(trainX)
train_pred = scaler.inverse_transform(train_pred)
trainY = trainY.reshape(trainY.shape[0] , 1)
trainY = scaler.inverse_transform(trainY)
print ('Display Accuracy Training Data')
display (r2_score(trainY,train_pred))
# Out:
# 26/26 [==============================] - 0s 3ms/step
# Display Accuracy Training Data
# 0.8557822131104839

# %%
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(trainY  , 'b')
plt.plot(train_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %%
stocks_pred = model.predict(stocksX)
stocks_pred = scaler.inverse_transform(stocks_pred)
stocksY = stocksY.reshape(stocksY.shape[0] , 1)
stocksY = scaler.inverse_transform(stocksY)
print ('Display Accuracy Training Data')
display (r2_score(stocksY,stocks_pred))
# Out:
# 32/32 [==============================] - 0s 3ms/step
# Display Accuracy Training Data
# 0.8470733834163575

# %%
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(stocksY  , 'b')
plt.plot(stocks_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()

# %%
# Extract the data related to company
results= df[df.symbol.isin ([i])]
results= results [2:]
results = results.reset_index(drop=True)
df_stocks_pred= pd.DataFrame(stocks_pred, columns = ['Close_Prediction'])
results= pd.concat([results,df_stocks_pred],axis =1)
results.to_excel('results.xlsx')
display(results)
# Out:
#             date symbol        open       close         low        high  \
# 0     2013-01-04     FB   28.010000   28.760000   27.830000   28.930000
# 1     2013-01-07     FB   28.690001   29.420000   28.650000   29.790001
# 2     2013-01-08     FB   29.510000   29.059999   28.860001   29.600000
# 3     2013-01-09     FB   29.670000   30.590000   29.490000   30.600000
# 4     2013-01-10     FB   30.600000   31.299999   30.280001   31.450001
# ...          ...    ...         ...         ...         ...         ...
# 1001  2016-12-23     FB  117.000000  117.269997  116.300003  117.559998
# 1002  2016-12-27     FB  116.959999  118.010002  116.860001  118.680000
# 1003  2016-12-28     FB  118.190002  116.919998  116.650002  118.250000
# 1004  2016-12-29     FB  117.000000  116.349998  116.059998  117.529999
# 1005  2016-12-30     FB  116.599998  115.050003  114.769997  116.830002
#
#            volume  Close_Prediction
# 0      72715400.0         42.864582
# ...
